# %% [markdown]
# <h1>Practica 2</h1>

# %% [markdown]
# <p>Objetivo:
#
# <li>Calcular estadísticas descriptivas básicas.</li>
# <li>Identificar las entidades y relaciones.</li>
# <li>Dibujar el diagrama de relaciones.</li>
# <li>Agrupar los datos por entidad y obtener estadísticas agrupadas.</li>
#
# </p>

# %% [markdown]
# <h3>Instalo librerias</h3>

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h3>Importo librerias</h3>

# %%
import pandas as pd

# %% [markdown]
# <h3>Cargo el dataset</h3>

# %%
df = pd.read_csv("csv/hour_cleaned.csv")
df.head()
# Out:
#        dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1   0        0        6           0           1
# 1  2011-01-01       1   0     1   1        0        6           0           1
# 2  2011-01-01       1   0     1   2        0        6           0           1
# 3  2011-01-01       1   0     1   3        0        6           0           1
# 4  2011-01-01       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# <h3>Calculo estadisticas descriptivas básicas</h3>

# %%
df.describe(include ='all')
# Out:
#             dteday        season            yr          mnth            hr  \
# count        17379  17379.000000  17379.000000  17379.000000  17379.000000
# unique         731           NaN           NaN           NaN           NaN
# top     2012-12-31           NaN           NaN           NaN           NaN
# freq            24           NaN           NaN           NaN           NaN
# mean           NaN      2.501640      0.502561      6.537775     11.546752
# std            NaN      1.106918      0.500008      3.438776      6.914405
# min            NaN      1.000000      0.000000      1.000000      0.000000
# 25%            NaN      2.000000      0.000000      4.000000      6.000000
# 50%            NaN      3.000000      1.000000      7.000000     12.000000
# 75%            NaN      3.000000      1.000000     10.000000     18.000000
# max            NaN      4.000000      1.000000     12.000000     23.000000
#
# ...

# %% [markdown]
# <h3>Agrupar por entidades  y obtener estadísticas</h3>

# %% [markdown]
# <h4>1. Agrupar por dia</h4>

# %%
df.groupby("dteday")["cnt"].sum().head()
# Out:
# dteday
# 2011-01-01     985
# 2011-01-02     801
# 2011-01-03    1349
# 2011-01-04    1562
# 2011-01-05    1600
# Name: cnt, dtype: int64

# %% [markdown]
# <h4>2. Agrupar por dia</h4>

# %%
df.groupby("hr")["cnt"].mean()
# Out:
# hr
# 0      53.898072
# 1      33.375691
# 2      22.869930
# 3      11.727403
# 4       6.352941
# 5      19.889819
# 6      76.044138
# 7     212.064649
# 8     359.011004
# 9     219.309491
# 10    173.668501
# 11    208.143054
# 12    253.315934
# 13    253.661180
# 14    240.949246
# 15    251.233196
# 16    311.983562
# 17    461.452055
# 18    425.510989
# 19    311.523352
# 20    226.030220
# 21    172.314560
# 22    131.335165
# 23     87.831044
# Name: cnt, dtype: float64

# %% [markdown]
# <h3>Diagrama</h3>

# %% [markdown]
# <img src= "assets/img/Diagrama.png">
